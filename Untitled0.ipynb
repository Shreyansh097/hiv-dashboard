# %%
# !pip install praise
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for praise: filename=praise-0.1-py3-none-any.whl size=4137 sha256=4d954d39a1357b953e926d38520346ec203e0ead36c7d15ec746c67a821f2b67
#   Stored in directory: /root/.cache/pip/wheels/78/db/a0/58b13c19f577a56e7111e1553a40c77f1816bdb01232e66fc8
# Successfully built praise
# ...

# %%
from praise import praise

# %%
praise()
# Out:
# 'You are charming!'

# %%
import matplotlib.pyplot as plt
# Data
my_power = [100, 100]
my_knowledge = ["without python", "with python"]
# Create bar plot
plt.bar(my_knowledge, my_power)
# Add labels
plt.xlabel("KNOWLEDGE LEVEL")
plt.ylabel("Power (NO.)")
plt.title("Bar Plot Example")
# Show plot
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Task
# Tell me about this dataset.
#
# Here is all the data you need:
# "unicef_indicator_1.csv"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the dataset "unicef_indicator_1.csv" into a pandas DataFrame.

# %%
# Out:
#   File "<ipython-input-13-fc0dc1e9878c>", line 1
#     Import pandas as pd
#            ^
# SyntaxError: invalid syntax
